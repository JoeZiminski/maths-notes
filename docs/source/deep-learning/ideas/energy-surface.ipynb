# %% [markdown]
# Something on the energy surface:
# 1) example with gaussians (show a few with different parameters
# 2) expectation over observed data
# 3) expectaion over all possible data
# 4) show functions, show how taking derviaives moves
# 5) done! going back between visualisations of p(x) over x and E(Ex) over theta
